# %%
import pandas as pd 
import numpy as np 
data = {"Customer_ID": [101, 102, 103, 103, 105, 106, 107, 108],  
        "Name": ["Akhil", "Meera", "Rahul", "Rahul", "Sneha", "Arjun", "Niya", "Farhan"], 
        "Age": [23, 27, np.nan, 31, 250, 29, 26, 35],    
        "Gender": ["Male", "Female", "M", "M", "female", "Male", "F", "male"],    
        "Salary": [25000, 32000, 28000, 28000, 45000, np.nan, 30000, 50000],    
        "City": ["Kochi", "Calicut", "Kochi", "Kochi", "Trivandrum", "Kochi", None, "Calicut"] }

# %%
df=pd.DataFrame(data)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=df[["Age", "Salary"]]
standardized = scaler.fit_transform(X)
print(standardized[:5])
# Out:
# [[-0.47871016 -1.01533693]
#  [-0.42715676 -0.22563043]
#  [        nan -0.67689129]
#  [-0.37560336 -0.67689129]
#  [ 2.4469454   1.24096736]]
