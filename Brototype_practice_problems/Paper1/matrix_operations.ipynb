# %%
def matrix_add(v1, v2):
    result= [[0 for x in range(len(v1[0]))]for y in range(len(v1))]
    for i in range(len(v1)):
        for j in range(len(v1[0])):
            result[i][j] = (v1[i][j]+v2[i][j])
    print(result)
A = [[2, 1], [0, 3]]
B = [[1, 4], [2, 1]]
matrix_add(A, B)
# Out:
# [[3, 5], [2, 4]]

# %%
A = [[2, 1], [0, 3]]
B = [[1, 4], [2, 1]]
def matrix_multiply(A, B):
    rows_A, cols_A = len(A), len(A[0])
    rows_B, cols_B = len(B), len(B[0])
    result=[[0 for y in range(len(B[0]))]for x in range(len(A))]
    for i in range(rows_A):
        for j in range(cols_B):
            for k in range(cols_A):
                result[i][j]+=A[i][k]*B[k][j]

    return result
print(matrix_multiply(A, B))
# Out:
# [[4, 9], [6, 3]]

# %%
v = [6, 8]
def magnitude(v):
    total=0
    for i in v:
        total+=i**2
    return total**0.5
print(magnitude(v))
# Out:
# 10.0

# %%
def dot_product(A, B):
    total=0
    for i in range(len(A)):
        total+=A[i]*B[i]
    return total
a = [2, 3, 1]
b = [4, 0, 5]
print(dot_product(a, b))
# Out:
# 13
