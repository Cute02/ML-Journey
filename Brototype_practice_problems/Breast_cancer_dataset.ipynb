# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

print("=== 1. SHAPE ===")
print(df.shape, "\n")

print("=== 2. TYPES ===")
print(df.dtypes.value_counts(), "\n")

print("=== 3. TARGET ===")
print("Classes:", data.target_names)
print(df['target'].value_counts(), "\n")

print("=== 4. MISSING VALUES ===")
print(df.isnull().sum().sum(), "missing values total\n")

print("=== 5. DISTRIBUTION (first 3 features) ===")
print(df.iloc[:, :3].describe(), "\n")

print("=== 6. CORRELATION with target (top 5) ===")
corr = df.corr()['target'].abs().sort_values(ascending=False)
print(corr[1:6])
# Out:
# === 1. SHAPE ===
# (569, 31)
#
# === 2. TYPES ===
# float64    30
# int64       1
# Name: count, dtype: int64
#
# === 3. TARGET ===
# Classes: ['malignant' 'benign']
# target
# 1    357
# 0    212
# Name: count, dtype: int64
#
# === 4. MISSING VALUES ===
# 0 missing values total
#
# === 5. DISTRIBUTION (first 3 features) ===
#        mean radius  mean texture  mean perimeter
# count   569.000000    569.000000      569.000000
# mean     14.127292     19.289649       91.969033
# std       3.524049      4.301036       24.298981
# min       6.981000      9.710000       43.790000
# 25%      11.700000     16.170000       75.170000
# 50%      13.370000     18.840000       86.240000
# 75%      15.780000     21.800000      104.100000
# max      28.110000     39.280000      188.500000
#
# === 6. CORRELATION with target (top 5) ===
# worst concave points    0.793566
# worst perimeter         0.782914
# mean concave points     0.776614
# worst radius            0.776454
# mean perimeter          0.742636
# Name: target, dtype: float64
